# %% [markdown]
# <a href="https://colab.research.google.com/github/syed653/00-odin-recipes/blob/main/Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Create your own Dictionary, with five of your friends' names and their phone numbers.

friends_contacts = {
    "Saka" : 07933893173,
    "Decs" : 07114173419,
    "Saliba" : 07381984813,
    "Gabriel" :07137646146,
    "Raya" : 073648176313
}

print(friends_contacts)
